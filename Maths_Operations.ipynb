# %% [markdown]
# # ARITHMETIC OPERATIONS IN PYTHON
# > By
# ### Tony Nwuzor

# %% [markdown]
# ### Assigning variables

# %%
a = 3

# %%
b = 6

# %% [markdown]
# ### Addition

# %%
c = a + b

# %%
c
# Out:
# 9

# %% [markdown]
# ### Subtraction

# %%
s = b - a

# %%
s
# Out:
# 3

# %% [markdown]
# ### Multiplication

# %%
m = a * b

# %%
m
# Out:
# 18

# %% [markdown]
# ### Division

# %%
d = b / a

# %%
d
# Out:
# 2.0

# %%
# To get just the whole number part
int(d)
# Out:
# 2
